# %% [markdown]
# """
# ================
# Real-time emotion recognition using webcam and microphone.
#
# Status: Planned for v2.0
# Requirements: sounddevice, opencv-python (already installed)
#
# Architecture:
#   1. Capture 3-second audio chunks via sounddevice
#   2. Capture simultaneous video frames via OpenCV webcam
#   3. Run EmotionPredictor.predict_from_arrays()
#   4. Overlay predicted emotion + confidence on the video frame
#   5. Display in real-time window
#
# Note: This requires a physical webcam and microphone.
#       The server environment (Linux/SSH) does not support
#       display windows. Run this locally on a desktop machine.
#
# Usage (when implemented):
#     python src/inference/realtime_demo.py --run cross_modal
# """
#
# # TODO: Implement in v2.0 for local desktop deployment
# raise NotImplementedError(
#     "Real-time demo requires local desktop environment with "
#     "webcam and microphone. See docstring for planned architecture."
# )
